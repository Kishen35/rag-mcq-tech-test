# %% [markdown]
# # DocuAsk - Stage 2 Interview Task - RAG System

# %% [markdown]
# ## Pre-Requisites

# %% [markdown]
# To perform OCR under the **Refined RAG Pipeline** section, [poppler](https://github.com/oschwartz10612/poppler-windows/releases) and [Tesseract-OCR](https://tesseract-ocr.github.io/) both need to be installed on the machine and added to PATH (System Properties > Environment Variables). This will require a restart of the terminal.

# %%
# %pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: ipykernel in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from -r requirements.txt (line 1)) (6.29.5)
# Requirement already satisfied: jupyter in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from -r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: nest_asyncio in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from -r requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: sentence-transformers in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from -r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: llama_index in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from -r requirements.txt (line 5)) (0.12.44)
# Requirement already satisfied: llama-index-llms-google-genai in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from -r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: llama-index-embeddings-google_genai in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from -r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: google-generativeai in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from -r requirements.txt (line 8)) (0.8.5)
# Requirement already satisfied: llama-index-embeddings_huggingface in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from -r requirements.txt (line 9)) (0.5.5)
# Requirement already satisfied: langchain-community in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from -r requirements.txt (line 11)) (0.3.26)
# Requirement already satisfied: langchain-core in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from -r requirements.txt (line 12)) (0.3.66)
# Requirement already satisfied: langchain-google-genai in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from -r requirements.txt (line 13)) (2.0.10)
# Requirement already satisfied: chromadb in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from -r requirements.txt (line 14)) (1.0.13)
# Requirement already satisfied: unstructured[pdf] in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from -r requirements.txt (line 10)) (0.18.1)
# Requirement already satisfied: comm>=0.1.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (9.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: packaging in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: psutil in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (27.0.0)
# Requirement already satisfied: tornado>=6.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: notebook in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (7.4.3)
# Requirement already satisfied: jupyter-console in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (6.6.3)
# Requirement already satisfied: nbconvert in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (7.16.6)
# Requirement already satisfied: ipywidgets in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: jupyterlab in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (4.4.4)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from sentence-transformers->-r requirements.txt (line 4)) (4.53.0)
# Requirement already satisfied: tqdm in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from sentence-transformers->-r requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from sentence-transformers->-r requirements.txt (line 4)) (2.7.1)
# Requirement already satisfied: scikit-learn in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from sentence-transformers->-r requirements.txt (line 4)) (1.7.0)
# Requirement already satisfied: scipy in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from sentence-transformers->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from sentence-transformers->-r requirements.txt (line 4)) (0.33.1)
# Requirement already satisfied: Pillow in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from sentence-transformers->-r requirements.txt (line 4)) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from sentence-transformers->-r requirements.txt (line 4)) (4.14.0)
# Requirement already satisfied: llama-index-agent-openai<0.5,>=0.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama_index->-r requirements.txt (line 5)) (0.4.12)
# Requirement already satisfied: llama-index-cli<0.5,>=0.4.2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama_index->-r requirements.txt (line 5)) (0.4.3)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.44 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama_index->-r requirements.txt (line 5)) (0.12.44)
# Requirement already satisfied: llama-index-embeddings-openai<0.4,>=0.3.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama_index->-r requirements.txt (line 5)) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama_index->-r requirements.txt (line 5)) (0.7.7)
# Requirement already satisfied: llama-index-llms-openai<0.5,>=0.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama_index->-r requirements.txt (line 5)) (0.4.7)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.6,>=0.5.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama_index->-r requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: llama-index-program-openai<0.4,>=0.3.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama_index->-r requirements.txt (line 5)) (0.3.2)
# Requirement already satisfied: llama-index-question-gen-openai<0.4,>=0.3.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama_index->-r requirements.txt (line 5)) (0.3.1)
# Requirement already satisfied: llama-index-readers-file<0.5,>=0.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama_index->-r requirements.txt (line 5)) (0.4.9)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama_index->-r requirements.txt (line 5)) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama_index->-r requirements.txt (line 5)) (3.9.1)
# Requirement already satisfied: google-genai>=1.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-llms-google-genai->-r requirements.txt (line 6)) (1.23.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-generativeai->-r requirements.txt (line 8)) (0.6.15)
# Requirement already satisfied: google-api-core in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-generativeai->-r requirements.txt (line 8)) (2.25.1)
# Requirement already satisfied: google-api-python-client in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-generativeai->-r requirements.txt (line 8)) (2.174.0)
# Requirement already satisfied: google-auth>=2.15.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-generativeai->-r requirements.txt (line 8)) (2.40.3)
# Requirement already satisfied: protobuf in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-generativeai->-r requirements.txt (line 8)) (5.29.5)
# Requirement already satisfied: pydantic in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-generativeai->-r requirements.txt (line 8)) (2.11.7)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai->-r requirements.txt (line 8)) (1.26.1)
# Requirement already satisfied: chardet in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (5.2.0)
# Requirement already satisfied: filetype in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: python-magic in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (0.4.27)
# Requirement already satisfied: lxml in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (6.0.0)
# Requirement already satisfied: requests in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (2.32.4)
# Requirement already satisfied: beautifulsoup4 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (4.13.4)
# Requirement already satisfied: emoji in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (2.14.1)
# Requirement already satisfied: dataclasses-json in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (0.6.7)
# Requirement already satisfied: python-iso639 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (2025.2.18)
# Requirement already satisfied: langdetect in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (1.0.9)
# Requirement already satisfied: numpy in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (2.3.1)
# Requirement already satisfied: rapidfuzz in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (3.13.0)
# Requirement already satisfied: backoff in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (2.2.1)
# Requirement already satisfied: unstructured-client in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (0.37.2)
# Requirement already satisfied: wrapt in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (1.17.2)
# Requirement already satisfied: python-oxmsg in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (0.0.2)
# Requirement already satisfied: html5lib in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (1.1)
# Requirement already satisfied: onnx>=1.17.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (1.18.0)
# Requirement already satisfied: onnxruntime>=1.19.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (1.22.0)
# Requirement already satisfied: pdf2image in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: pdfminer.six in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (20250506)
# Requirement already satisfied: pikepdf in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (9.9.0)
# Requirement already satisfied: pi-heif in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: pypdf in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (5.7.0)
# Requirement already satisfied: google-cloud-vision in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (3.10.2)
# Requirement already satisfied: effdet in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (0.4.1)
# Requirement already satisfied: unstructured-inference>=1.0.5 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (1.0.5)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 10)) (0.3.15)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from langchain-community->-r requirements.txt (line 11)) (0.3.26)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from langchain-community->-r requirements.txt (line 11)) (2.0.41)
# Requirement already satisfied: PyYAML>=5.3 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from langchain-community->-r requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from langchain-community->-r requirements.txt (line 11)) (3.12.13)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from langchain-community->-r requirements.txt (line 11)) (8.5.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from langchain-community->-r requirements.txt (line 11)) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from langchain-community->-r requirements.txt (line 11)) (0.4.4)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from langchain-community->-r requirements.txt (line 11)) (0.4.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from langchain-core->-r requirements.txt (line 12)) (1.33)
# Requirement already satisfied: build>=1.0.3 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (1.2.2.post1)
# Requirement already satisfied: pybase64>=1.4.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 14)) (0.35.0)
# Requirement already satisfied: posthog>=2.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (6.0.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (7.7.0)
# Requirement already satisfied: importlib-resources in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from chromadb->-r requirements.txt (line 14)) (4.24.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 11)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 11)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 11)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 11)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 11)) (6.6.2)
# Requirement already satisfied: propcache>=0.2.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 11)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 11)) (1.20.1)
# Requirement already satisfied: pyproject_hooks in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 14)) (1.2.0)
# Requirement already satisfied: colorama in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 14)) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from dataclasses-json->unstructured[pdf]->-r requirements.txt (line 10)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from dataclasses-json->unstructured[pdf]->-r requirements.txt (line 10)) (0.9.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-api-core->google-generativeai->-r requirements.txt (line 8)) (1.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-auth>=2.15.0->google-generativeai->-r requirements.txt (line 8)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-auth>=2.15.0->google-generativeai->-r requirements.txt (line 8)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-auth>=2.15.0->google-generativeai->-r requirements.txt (line 8)) (4.9.1)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-genai>=1.4.0->llama-index-llms-google-genai->-r requirements.txt (line 6)) (4.9.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-genai>=1.4.0->llama-index-llms-google-genai->-r requirements.txt (line 6)) (15.0.1)
# Requirement already satisfied: certifi in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 14)) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 14)) (1.0.9)
# Requirement already satisfied: idna in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 14)) (3.10)
# Requirement already satisfied: h11>=0.16 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb->-r requirements.txt (line 14)) (0.16.0)
# Requirement already satisfied: filelock in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers->-r requirements.txt (line 4)) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers->-r requirements.txt (line 4)) (2025.5.1)
# Requirement already satisfied: decorator in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.19.2)
# Requirement already satisfied: stack_data in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: jsonpointer>=1.9 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core->-r requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 14)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 14)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 14)) (0.25.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 1)) (4.3.8)
# Requirement already satisfied: pywin32>=300 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 1)) (310)
# Requirement already satisfied: six>=1.9.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 14)) (1.17.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 14)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 14)) (3.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 14)) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 14)) (0.10)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community->-r requirements.txt (line 11)) (0.3.8)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from langsmith>=0.1.125->langchain-community->-r requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from langsmith>=0.1.125->langchain-community->-r requirements.txt (line 11)) (0.23.0)
# Requirement already satisfied: openai>=1.14.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-agent-openai<0.5,>=0.4.0->llama_index->-r requirements.txt (line 5)) (1.93.0)
# Requirement already satisfied: aiosqlite in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-core<0.13,>=0.12.44->llama_index->-r requirements.txt (line 5)) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-core<0.13,>=0.12.44->llama_index->-r requirements.txt (line 5)) (2.1.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-core<0.13,>=0.12.44->llama_index->-r requirements.txt (line 5)) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-core<0.13,>=0.12.44->llama_index->-r requirements.txt (line 5)) (1.0.8)
# Requirement already satisfied: llama-index-workflows<2,>=1.0.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-core<0.13,>=0.12.44->llama_index->-r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: networkx>=3.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-core<0.13,>=0.12.44->llama_index->-r requirements.txt (line 5)) (3.5)
# Requirement already satisfied: setuptools>=80.9.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-core<0.13,>=0.12.44->llama_index->-r requirements.txt (line 5)) (80.9.0)
# Requirement already satisfied: tiktoken>=0.7.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-core<0.13,>=0.12.44->llama_index->-r requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: llama-cloud==0.1.26 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama_index->-r requirements.txt (line 5)) (0.1.26)
# Requirement already satisfied: pandas<2.3.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama_index->-r requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama_index->-r requirements.txt (line 5)) (0.0.26)
# Requirement already satisfied: soupsieve>1.2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from beautifulsoup4->unstructured[pdf]->-r requirements.txt (line 10)) (2.7)
# Requirement already satisfied: llama-parse>=0.5.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-readers-llama-parse>=0.4.0->llama_index->-r requirements.txt (line 5)) (0.6.34)
# Requirement already satisfied: click in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from nltk>3.8.1->llama_index->-r requirements.txt (line 5)) (8.2.1)
# Requirement already satisfied: joblib in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from nltk>3.8.1->llama_index->-r requirements.txt (line 5)) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from nltk>3.8.1->llama_index->-r requirements.txt (line 5)) (2024.11.6)
# Requirement already satisfied: coloredlogs in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from onnxruntime>=1.19.0->unstructured[pdf]->-r requirements.txt (line 10)) (15.0.1)
# Requirement already satisfied: flatbuffers in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from onnxruntime>=1.19.0->unstructured[pdf]->-r requirements.txt (line 10)) (25.2.10)
# Requirement already satisfied: sympy in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from onnxruntime>=1.19.0->unstructured[pdf]->-r requirements.txt (line 10)) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 14)) (8.7.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 14)) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 14)) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb->-r requirements.txt (line 14)) (0.55b1)
# Requirement already satisfied: distro>=1.5.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from posthog>=2.4.0->chromadb->-r requirements.txt (line 14)) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from pydantic->google-generativeai->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from pydantic->google-generativeai->-r requirements.txt (line 8)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from pydantic->google-generativeai->-r requirements.txt (line 8)) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community->-r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from requests->unstructured[pdf]->-r requirements.txt (line 10)) (3.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from rich>=10.11.0->chromadb->-r requirements.txt (line 14)) (3.0.0)
# Requirement already satisfied: greenlet>=1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community->-r requirements.txt (line 11)) (3.2.3)
# Requirement already satisfied: jinja2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: safetensors>=0.4.3 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r requirements.txt (line 4)) (0.5.3)
# Requirement already satisfied: shellingham>=1.3.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from typer>=0.9.0->chromadb->-r requirements.txt (line 14)) (1.5.4)
# Requirement already satisfied: python-multipart in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]->-r requirements.txt (line 10)) (0.0.20)
# Requirement already satisfied: opencv-python!=4.7.0.68 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]->-r requirements.txt (line 10)) (4.11.0.86)
# Requirement already satisfied: matplotlib in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]->-r requirements.txt (line 10)) (3.10.3)
# Requirement already satisfied: timm in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]->-r requirements.txt (line 10)) (1.0.16)
# Requirement already satisfied: accelerate in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]->-r requirements.txt (line 10)) (1.8.1)
# Requirement already satisfied: pypdfium2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]->-r requirements.txt (line 10)) (4.30.1)
# Requirement already satisfied: httptools>=0.6.3 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 14)) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 14)) (1.1.0)
# Requirement already satisfied: torchvision in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from effdet->unstructured[pdf]->-r requirements.txt (line 10)) (0.22.1)
# Requirement already satisfied: pycocotools>=2.0.2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from effdet->unstructured[pdf]->-r requirements.txt (line 10)) (2.0.10)
# Requirement already satisfied: omegaconf>=2.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from effdet->unstructured[pdf]->-r requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-api-python-client->google-generativeai->-r requirements.txt (line 8)) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-api-python-client->google-generativeai->-r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-api-python-client->google-generativeai->-r requirements.txt (line 8)) (4.2.0)
# Requirement already satisfied: webencodings in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from html5lib->unstructured[pdf]->-r requirements.txt (line 10)) (0.5.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 2)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 2)) (3.0.15)
# Requirement already satisfied: async-lru>=1.0.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (2.0.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (0.2.4)
# Requirement already satisfied: bleach!=5.0.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 2)) (6.2.0)
# Requirement already satisfied: defusedxml in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: cryptography>=36.0.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from pdfminer.six->unstructured[pdf]->-r requirements.txt (line 10)) (45.0.4)
# Requirement already satisfied: olefile in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from python-oxmsg->unstructured[pdf]->-r requirements.txt (line 10)) (0.47)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: aiofiles>=24.1.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from unstructured-client->unstructured[pdf]->-r requirements.txt (line 10)) (24.1.0)
# Requirement already satisfied: sniffio>=1.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai>=1.4.0->llama-index-llms-google-genai->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: griffe in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.44->llama_index->-r requirements.txt (line 5)) (1.7.3)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: cffi>=1.14 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[pdf]->-r requirements.txt (line 10)) (1.17.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai->-r requirements.txt (line 8)) (1.71.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai->-r requirements.txt (line 8)) (3.2.3)
# Requirement already satisfied: zipp>=3.20 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 14)) (3.23.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: prometheus-client>=0.9 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.18.1)
# Requirement already satisfied: babel>=2.10 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 2)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-index-workflows<2,>=1.0.1->llama-index-core<0.13,>=0.12.44->llama_index->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: llama-cloud-services>=0.6.32 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama_index->-r requirements.txt (line 5)) (0.6.34)
# Requirement already satisfied: mdurl~=0.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->-r requirements.txt (line 14)) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter->-r requirements.txt (line 2)) (2.21.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from omegaconf>=2.0->effdet->unstructured[pdf]->-r requirements.txt (line 10)) (4.9.3)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama_index->-r requirements.txt (line 5)) (0.10.0)
# Requirement already satisfied: pytz>=2020.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama_index->-r requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama_index->-r requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: wcwidth in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai->-r requirements.txt (line 8)) (0.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from sympy->onnxruntime>=1.19.0->unstructured[pdf]->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[pdf]->-r requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from coloredlogs->onnxruntime>=1.19.0->unstructured[pdf]->-r requirements.txt (line 10)) (10.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]->-r requirements.txt (line 10)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]->-r requirements.txt (line 10)) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]->-r requirements.txt (line 10)) (1.4.8)
# Requirement already satisfied: executing>=1.2.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pure-eval in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: argon2-cffi-bindings in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (21.2.0)
# Requirement already satisfied: pycparser in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six->unstructured[pdf]->-r requirements.txt (line 10)) (2.22)
# Requirement already satisfied: pyreadline3 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.19.0->unstructured[pdf]->-r requirements.txt (line 10)) (3.5.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: rfc3339-validator in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.1.1)
# Requirement already satisfied: fqdn in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: isoduration in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (20.11.0)
# Requirement already satisfied: uri-template in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (24.11.1)
# Requirement already satisfied: arrow>=0.15.0 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in d:\code\docuask\rag-mcq-tech-test\venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (2.9.0.20250516)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ (d:\Code\DocuAsk\rag-mcq-tech-test\venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (d:\Code\DocuAsk\rag-mcq-tech-test\venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (d:\Code\DocuAsk\rag-mcq-tech-test\venv\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Execute Asychrounously
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### Configuration

# %%
# LLM & Embedding Settings

llm = "gemini-2.0-flash" 
api_key = "AIzaSyArw7MwjRaQjh1it6w6mngXc8NNI4G7FOM" # Gemini API Key
delay = 7  # Delay in seconds between requests to prevent rate limiting - suggested 7 seconds for gemini-2.0-flash

embedding_model = "BAAI/bge-small-en-v1.5"  # HuggingFace Embedding Model

# %% [markdown]
# ## Basic RAG Pipeline with LlamaIndex

# %%
from llama_index.core import Settings

# Configure the LLM
from llama_index.llms.google_genai import GoogleGenAI
Settings.llm = GoogleGenAI(model=llm, api_key=api_key, generate_kwargs={"max_output_tokens": 1}) # only one answer "A, B, C, D"

# Configure the Embedding Model
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
Settings.embed_model = HuggingFaceEmbedding(model_name=embedding_model)

# Google GenAI Embeddings (usually more accurate)
# from llama_index.embeddings.google_genai import GoogleGenAIEmbedding
# Settings.embed_model = GoogleGenAIEmbedding(api_key=api_key)

# %% [markdown]
# ### Ingestion
#  1. Load all PDFs
#  2. Create a VectorStoreIndex using the HuggingFace Embedding Model
#  3. Save to `index` directory

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

PDF_DIR = 'data/5_estate_planning/Lessons/'
INDEX_DIR = 'index'

# 1. Load all PDF files from the specified directory
try:
    documents = SimpleDirectoryReader(PDF_DIR).load_data()
    print(f"Loaded {len(documents)} documents from {PDF_DIR}")
except Exception as e:
    print(f"Error loading documents: {e}")
    documents = [] # Ensure documents is an empty list if loading fails

# 2. Create a VectorStoreIndex from the loaded documents
if documents:
    print("Creating VectorStoreIndex...")
    index = VectorStoreIndex.from_documents(documents)
    print("VectorStoreIndex created successfully.")

    # 3. Save the index to disk
    print(f"Saving index to disk in directory '{INDEX_DIR}'...")
    index.storage_context.persist(persist_dir=INDEX_DIR)
    print("Index saved successfully.")
else:
    print("No documents loaded, index creation skipped.")
# Out:
# Loaded 140 documents from data/5_estate_planning/Lessons/
# Creating VectorStoreIndex...
# VectorStoreIndex created successfully.
# Saving index to disk in directory 'index'...
# Index saved successfully.

# %% [markdown]
# ### Retrieval
#
# - Load the indexes from storage
# - Read the multiple-choice questions from the JSON file

# %%
import json
import os
from llama_index.core import StorageContext, load_index_from_storage
import re
import time
from llama_index.core.response import Response


# Define the directory where the index is saved
INDEX_DIR = 'index'

# Define the path to the questions JSON file
QUESTIONS_FILE = 'data/processed/5_estate_planning_questions.json'


# Load the index
print(f"Attempting to load index from {INDEX_DIR}")
try:
    # Try loading from storage context (assuming it was saved that way)
    if os.path.exists(INDEX_DIR):
        from llama_index.core import StorageContext, load_index_from_storage
        storage_context = StorageContext.from_defaults(persist_dir=INDEX_DIR)
        index = load_index_from_storage(storage_context) # loaded index
        print(f"Successfully loaded index from {INDEX_DIR} using StorageContext")
except Exception as e:
    print(f"An unexpected error occurred while loading index: {e}")
    print("Could not load the index. Please ensure the index is created and saved correctly.")
    exit()


# Read the questions and expected answers from the JSON file
try:
    with open(QUESTIONS_FILE, 'r') as f:
        questions_data = json.load(f)
    print(f"Successfully loaded questions from {QUESTIONS_FILE}")
except FileNotFoundError:
    print(f"Error: Questions file not found at {QUESTIONS_FILE}")
    exit()
except json.JSONDecodeError:
    print(f"Error: Could not decode JSON from {QUESTIONS_FILE}")
    exit()

# index - contains the loaded index
# questions_data - contains the list of questions and expected answers.
# Out:
# Attempting to load index from index
# Loading llama_index.core.storage.kvstore.simple_kvstore from index\docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from index\index_store.json.
# Successfully loaded index from index using StorageContext
# Successfully loaded questions from data/processed/5_estate_planning_questions.json

# %% [markdown]
# ### Synthesis
# Use the `query_engine` to:
# 1. Retrieve relevant content from the indexed documents -> context
# 2. Send the both the context & multiple-choice question to the LLM

# %%
# Process each question using the index and an LLM.
query_engine = index.as_query_engine()

correct_answers = 0

for chapter_key, questions_list in questions_data.items():
    for question_entry in questions_list:

        question_text = question_entry['question']
        expected_answer = question_entry['answer']

        # Construct the query with explicit instructions to only return the letter answer
        query_text = f"""\
        You are an agent designed to answer a multiple choice question over a set of given documents.
        You must respond with ONLY the letter of the correct answer: A, B, C, or D.
        Do NOT include any explanation, reasoning, or extra text.
        If you include anything other than A, B, C, or D, your answer will be considered invalid. \n
        Question: {question_text}
        """

        # Get response from the RAG system
        response: Response = query_engine.query(query_text)
        
        # Add a small delay to avoid hitting API rate limits
        time.sleep(delay)

        # Print details for analysis
        print("-" * 20)
        print(f"Question: {question_text}")
        print(f"Expected Answer: {expected_answer}")
        # print("Retrieved Context:")
        # for node in response.source_nodes:
        #     print(node.text)
        #     print("-" * 10)
        print(f"Raw LLM Response: {str(response)}")
        print("-" * 20) # Ensure this is consistent

        # ANSWER SELECTION: Use regex to extract the predicted answer (a single uppercase letter A-D)
        match = re.search(r'[A-D]', str(response).strip().upper())
        predicted_answer = match.group(0) if match else None

        # Compare predicted and expected answers
        if predicted_answer == expected_answer:
            correct_answers += 1
# Out:
# --------------------
# Question: 1. In Estate Planning there are many views and approaches taken. Which of the following is not true?
#
# A. It is common for many Malaysians to avoid estate planning
#
# B. Writing a Will is adequate for estate planning purposes
#
# C. People generally tend to avoid estate planning because it is a complex subject.
#
# D. Preservation of the estate is a key objective in estate planning
# Expected Answer: B
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 2. The various steps in the process of estate planning ensure that all issues are covered. Which of the following sequence in the process is correct?
#
# A. Set Objectives â€“ Gather information â€“ Implement â€“ Develop a plan â€“ Review
#
# B. Set Objectives â€“ Gather information â€“ Review â€“ Implement â€“ Develop a plan
#
# C. Gather information â€“ Set Objectives â€“ Review â€“ Implement â€“ Develop a plan
#
# D. Set Objectives â€“ Gather information â€“ Develop a plan â€“ Implement â€“ Review
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 3. The following statement(s) is/are not correct:
#
# I. Accumulation, Conservation and Distribution are issues that a person needs to address in his life-time.
#
# II. Assets held in joint names are not considered as part of the estate of a deceased co-owner.
#
# III. Debts, royalties and rights to compensation damages are included in an estate of a deceased.
#
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All the above
# Expected Answer: B
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 4. There are many purposes of estate planning, which of the following statement(s) is/are correct?
#
# I. Ensure liquidity for cost of transfer fees and expenses
#
# II. Assets are sufficient to meet objectives
#
# III. Minimise depleting the value of assets
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All the above
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 5. Included in the several phases of estate planning are various considerations. Which of the following is not correct?
#
# A. Ensure that a desired lifestyle is definitely possible
#
# B. Wealth creation is the logical start for estate planning
#
# C. Life insurance helps in wealth creation
#
# D. Estate shrinkage can be due to unpaid income taxes
# Expected Answer: A
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 6. Upon death, the property of a deceased estate owner passes to other in a number of ways. Which of the following is/are correct?
#
# A. By validating the will through the courts
#
# B. By assignment of title of immovable assets
#
# C. By mechanism of survivorship
#
# D. All the above
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 7. During the Implementation stage of the estate plan, which of the following is not important?
#
# A. Execution of all necessary legal documents
#
# B. Ensure marital stability and family harmony
#
# C. Provide for liquidity emergencies
#
# D. Objectives of estate owner and mechanisms must be consistent
# Expected Answer: B
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 8. Concerning ownership of property, which statement is not correct?
#
# A. Under term interest, the right to process, use and derive income ceases at the end of the term
#
# B. The holder of an unlimited interest in the property has outright ownership
#
# C. Participants in a tenancy in common have survivorship rights
#
# D. Participants in a joint tenancy have survivorship rights
# Expected Answer: C
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 9. The following statements are about objectives of an estate plan. Which of the statement(s) is/are correct?
#
# I. The ultimate purpose of an estate plan is to facilitate the transfer of beneficial interest of the assets to the trustees
#
# II. It is important to understand the needs of each beneficiary in order to match the most appropriate distribution item.
#
# III. Beneficiaries need to await completion of the probate or administration process before receiving the distribution.
#
# A. I and II only
#
# B. II and III only
#
# C. I and III only
#
# D. All of the above
# Expected Answer: B
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 10. Which one of the following is not an Estate Planning tool.
#
# A. Will
#
# B. Trust
#
# C. Tenancy Agreement
#
# D. Power of Attorney
# Expected Answer: C
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 1. The following statements relate to Probate Estates. Which of the statement(s) is/are correct?
#
# I. The Will determines the distribution of all the assets of the deceased
#
# II. Probate estate encompasses all property passed to others by a Will.
#
# III. The law that prescribes the rules for the grant of representation in Malaysia is the Distribution (Amendment) Act 1997.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All of the above
# Expected Answer: B
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 2. The probate process proves the validity of the Will and it addresses many issues. Which one of the following is not correct?
#
# I. Settlement of the estate
#
# II. Distribution of the entire assets of the deceased
#
# III. Avoids disputes pertaining to the deceased owner's Will
#
# IV. Appointment of personal representatives of the estate
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. IV only
# Expected Answer: B
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 3. Which one of the following statements is not correct?
#
# I. If an estate owner dies without a valid will, all probate property passes under the laws of intestate succession.
#
# II. Non-probate property are those that are passed on to beneficiaries by operation of law or by contract.
#
# III. Life insurance policies assigned either conditionally or absolutely to third parties are non-probate assets.
#
# IV. Tenancy in common is an example of transfer by operation of law.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. IV only
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 4. A number of legislations impact estate planning. Which of the following is no longer relevant?
#
# A. Wills Act 1959 (Revised 1998)
#
# B. Probate and Administration Act 1959 (revised 1972)
#
# C. Finance (Estate Duty) Act 1980 (Amended 1984)
#
# D. Distribution (Amendment) Act 1997
# Expected Answer: C
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 5. The purposes of preparing a Will should be made known. Which of the statement(s) is/are correct?
#
# A. Ensuring the right people handle the testator's property.
#
# B. Ensuring the right people receive the property.
#
# C. Ensuring a smooth transfer of the deceased's property.
#
# D. All the above are correct.
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 6. With reference to the validity of a Will for Non-Muslims which of the statement(s) is/are correct?
#
# I. All Wills must fully comply with the provisions of the Wills Act 1959.
#
# II. The testator must be of sound mind.
#
# III. The Will must be in writing.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 7. Which of the following is not correct concerning Wills?
#
# A. A Will can also be made by persons aged less than 18.
#
# B. The mode of execution of the Will is a factor to take into account for a valid Will.
#
# C. Oral Will does not comply with the Wills Act 1959
#
# D. There has to be two witnesses to the will.
# Expected Answer: A
# Raw LLM Response: A
#
# --------------------
# --------------------
# Question: 8. Which of these statement(s) is/are correct concerning Wills and Probate?
#
# A. The probate process is for the purpose of proving that the Will is valid.
#
# B. The probate process gets the Will and the executor named in the Will to be legally approved by the Court.
#
# C. There are specific rules and procedures to follow in the probate process.
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 9. The Distribution Act 1958 (and the Amendment Act 1997) applies to
#
# A. Peninsular Malaysia and Sabah only.
#
# B. Peninsular Malaysia and Sarawak only.
#
# C. Sabah and Sarawak only.
#
# D. The whole of Malaysia.
# Expected Answer: B
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 10. When a testator signs a Will, the witnesses .
#
# A. Need to sign in isolation but do not need to read the Will.
#
# B. Need to sign in the presence of the testator but do not need to read the Will.
#
# C. Need to read the Will in the presence of each other
#
# D. Need to read the Will in the presence of the testator.
# Expected Answer: B
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 1. For Muslims, estate planning may be more structured. Which of the following statement(s)
# is/are correct?
#
# I. The Wills Act 1959 does not apply to Muslims making a Will in Malaysia.
#
# II. For distribution of property the Syariah laws of the Shaffi School of Islamic Jurisprudence
# applies.
# III. Property acquired during marriage is called Harta Sepencarian and will pass on to the
# surviving spouse and children.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All of the above
# Expected Answer: C
# Raw LLM Response: A
#
# --------------------
# --------------------
# Question: 2. The terminology used that relates to estate planning for Muslims include the following. Which
# amongst the list is not correct?
#
# I. The Wasiat is a Muslim will.
#
# II. Gifts given away inter vivos is called Hibah.
#
# III. Faraid refers to testate distribution of Muslim property.
#
# IV. Baitulmal refers to funds of the Muslim community
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. IV only
# Expected Answer: C
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 3. Which of the following of the hukum faraid distribution are correct?
#
# I. If the wife dies leaving a husband, son and daughter, the husband is entitled to Â¼ of the
# estate, the son Â½ and the daughter Â¼.
# II. If there are no children and the husband survives the wife, the husband receives Â½ of the
# estate and the balance goes to Baitulmal.
# III. If the husband dies leaving a wife, son and daughter, the wife receives 1/8, the son 7/12,
# the daughter 7/24.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All are correct
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 4. Muslims are advised to write a will. The main advantage is
#
# A. The entire estate may be given to non legal heirs if desired
#
# B. It would be easier to administer the estate because of the Probate process.
#
# C. The estate distribution need not follow hukum faraid principles
#
# D. At least two-thirds of the estate may be given to non-muslims if desired.
# Expected Answer: B
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 5. With reference to administration of the estates of Muslim. Which of the following are true?
#
# I. The Wills Act 1959 applies to Muslims
#
# II. The Probate and Administration Act 1959 applies to Muslims
#
# III. The Statutory Trust created by Paragraph 5 of Schedule 10 (Section 130) of Financial
# Services Act 2013 does not apply to Muslims
# IV. Muslims are not allowed to apply for administration under the Small Estates (Distribution)
# Act 1955.
#
# A. I and II only
#
# B. I and III only
#
# C. II and III only
#
# D. II and IV only
# Expected Answer: C
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 6. Which of the following are true?
#
# I. Non-Muslims cannot inherit form the estate of a Muslim
#
# II. A Muslim testator can Will away at least one-quarter of his estate to non legal heirs.
#
# III. By means of a valid disposition, a Muslim can give away less than one-third of his estate
# to Non-Muslims.
#
# A. I and II only
#
# B. I and III only
#
# C. II and III only
#
# D. All the above
# Expected Answer: D
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 7. During their life-time, Muslims are allowed to give inter-vivos gifts. The following, except one
# are examples of such gifts
#
# A. Transfer of house
#
# B. Absolutely assignment of a life insurance policy
#
# C. Naming a nominee of life insurance policy moneys
#
# D. Irrevocable trusts
# Expected Answer: C
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 8. The â€žSijil Faraidâ€Ÿ is
#
# A. Given by the High Court
#
# B. Equivalent to the Letters of Administration
#
# C. A Certificate confirming the benefit of the legal heirs
#
# D. A Distribution Order given by Amanah Raya Bhd
# Expected Answer: C
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 9. Upon the death of a EPF contributor, who is a Muslim. The moneys are paid
#
# A. only upon obtaining the Sijil Faraid
#
# B. only after the Will has gone through the Probate process
#
# C. to the named nominee
#
# D. only to the administrator of the estate.
# Expected Answer: C
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 10. Which one of the following features of the Islamic law of distribution is true?
#
# A. The wife of the deceased is always entitled to a quarter of the estate
#
# B. The husband of the deceased always inherits half the estate
#
# C. The wife of the deceased inherits the whole estate if she is the only legal heir surviving
#
# D. Where the deceased leaves one daughter as the only legal heir, she inherits only half the
# estate
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 1. With reference to Trustees, which of the following statement(s) is/are correct?
#
# I. The powers of the trustee are governed by an Act of Parliament.
#
# II. The court cannot step in should a trustee fail in carrying out his duty.
#
# III. A maximum of five trustees can be appointed for family trusts.
#
# IV. In the absence of trustees the benefit of a trust is still effective.
#
# A. I and II only
#
# B. II and III only
#
# C. II and IV only
#
# D. I and IV only
# Expected Answer: D
# Raw LLM Response: A
#
# --------------------
# --------------------
# Question: 2. Which of these statements is not correct with reference to the uses of trusts in estate planning?
#
# A. The trustee has a fiduciary duty to act in the interest of the beneficiaries.
#
# B. A trust creates an equitable obligation that is strictly imposed by the court of law
#
# C. Trust properties are those assets that have been transferred to the trustee to be held for the benefit of beneficiaries.
# D. The Trustee Act 1949 defines the duties of the trustee and it overrides the trust deed.
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 3. Which of the statements below are correct with reference to the components of trusts?
#
# I. A life insurance policy assigned to a trustee for the beneficiaries is part of the 'Trust Corpus' or assets of the trust.
# II. The trust deed can provide instructions to the trustees to manage and distribute life insurance proceeds irrespective whether the life policy was created through statutory or non-statutory means.
# III. Beneficiaries have legally enforceable rights that enable them to defend and protect their interest in the trust.
#
# A. All are correct except (I)
#
# B. All are correct except (II)
#
# C. All are correct except (III)
#
# D. All are correct
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 4. With reference to the classification of trusts, which of the following is/are correct?
#
# I. The naming of nominees who are spouse, children or parents (where there is no spouse or child) in a life policy creates a Statutory Trust.
# II. Should a settlor set up a trust without naming or identifying the beneficiary, a Resulting Trust is formed where the beneficial interest reverts back to the settlor.
# III. Where the settlor has specified exact interest or share proportions for beneficiaries in the trust, a Fixed Trust has been set up.
# IV. In a Discretionary Trust, the trustee has the discretion to decide on how much of the trust property is to be distributed for each beneficiary.
#
# A. All of the above
#
# B. I and II only
#
# C. II and III only
#
# D. III and IV only
# Expected Answer: A
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 5. With reference to Testamentary Trusts, which of these statements is not correct?
#
# I. This is trust created by means of the will following the testator's death.
#
# II. The trust can only come into effect after probate has been obtained.
#
# III. Secrecy of assets and contents of a testamentary trust can be kept confidential after the death of a testator.
# IV. A testamentary trust will become irrevocable upon the death of the testator.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. IV only
# Expected Answer: C
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 6. When a trust is created, who has legal title and equitable ownership?
#
# A. Beneficiary (legal title) and Trustee (equitable ownership).
#
# B. Beneficiary (legal title) and Settlor (equitable ownership).
#
# C. Trustee (legal title) and Beneficiary (equitable ownership).
#
# D. Trustee (legal title) and Settlor (equitable ownership).
# Expected Answer: C
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 7. Chan transfers property to Lim and directs that the income derived shall be paid to Angela. Which of the following is the right option
#
# A. Chan (Beneficiary), Lim (Trustee), Angela (Settlor)
# B. Chan (Settlor), Lim (Beneficiary), Angela (Trustee)
# C. Chan (Trustee), Lim (Settlor), Angela (Beneficiary)
# D. Chan (Settlor), Lim (Trustee), Angela (Beneficiary)
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 8. Which of the following is not true with reference to the general principles of trusts?
#
# A. A settlor transfers legal ownership to trustees
#
# B. Trusts may be created by a Will
#
# C. Beneficiaries may not be trustees
#
# D. Trustees must consult the settlor in all dealings concerning the trust
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 9. What is a testamentary trust?
#
# A. It is a trust created under a Will and is revocable before the Testator's death.
#
# B. It is a trust created under a Power of Attorney and is never irrevocable until the Donor's death.
# C. It is a trust created by operation of law.
#
# D. It is a trust created by court
# Expected Answer: A
# Raw LLM Response: A
#
# --------------------
# --------------------
# Question: 10. In his Will, Mr Tan leaves "the majority of my shares in Genting Resorts Bhd to Mr Chin for the benefit of my children". What is the consequence of this instruction?
#
# 1. The trust will fail for lack of certainty of objects (beneficiaries)
#
# 2. The trust will fail for lack of certainty of subject matter
#
# 3. The trust will fail for lack of certainty of words
#
# 4. The shares will be part of a Resulting Trust in favour of the children only
#
# 5. The shares will become part of the residue
#
# A. 1 and 4 only
#
# B. 2 and 5 only
#
# C. 3 and 5 only
#
# D. 1,2 and 4 only
# Expected Answer: B
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 1. With reference to a Power of Attorney, which of the following statement(s) is/are
# correct?
#
# I. The Durable Power of Attorney authorises a trusted person to make financial decisions for
# an individual should the person become unable to do so himself.
#
# II. The person appointed in the Durable Power of Attorney is called the Attorney or Donee
#
# III. The death or mental incapacity of the Donor revokes a simple Power of Attorney.
#
# IV. The death or legal incapacity or bankruptcy of the Donee revokes a Power of attorney.
#
# A. I and II only
#
# B. II and III only
#
# C. I and III only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 2. On matters relating to the Power of Attorney, which of these is not correct?
#
# I. A Power of Attorney can be made irrevocable or durable where there is valuable
# consideration given and is expressed to be irrevocable.
# II. Where a Power of Attorney is made irrevocable for a fixed period it cannot be revoked by
# the death of the donor during that period.
#
# III. Under a General Power of Attorney the attorney can handle all the donor's insurance
# needs and claims.
# IV. Under  a  General  Power  of  Attorney  the  attorney  cannot  file  tax  returns  and make
# payments.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. IV only
# Expected Answer: D
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 3. What is a Power of Attorney?
#
# A. A power granted by Court to a Trustee to execute the Trust Deed
#
# B. An assignment by an assignor to an assignee
#
# C. A power granted by Court to an executor to execute the Will
#
# D. An instruction by which a Donor may formally authorise a Donee to act on his behalf or be
# his agent.
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 4. A Power of Attorney operates on the following principles:-
#
# A. Contractual Principles
#
# B. Tort Principles
#
# C. Trust Principles
#
# D. Agency Principles
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 5. Which of the following usually revoke a Power of Attorney?
#
# I. Death
#
# II. Marriage
#
# III. Divorce
#
# IV. Not in the country
#
# V. Bankruptcy
#
# A. IV only
#
# B. I and V only
#
# C. I and II and V only
#
# D. I and II and IV only
# Expected Answer: B
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 6. In order to be valid a Power of Attorney must be registered/deposited with:
#
# A. Land Office
#
# B. High Court
#
# C. Department of Insolvency
#
# D. Amanah Raya Berhad
# Expected Answer: B
# Raw LLM Response: I am sorry, but this question cannot be answered from the given context.
#
# --------------------
# --------------------
# Question: 7. The Authentication of a Power of Attorney must be done before either one of the following
# persons with the exception of:
#
# A. Magistrate
#
# B. Police Inspector
#
# C. Commissioner for Oaths
#
# D. Justice of Peace
# Expected Answer: B
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 8. In what circumstances can a Power of Attorney be said to be irrevocable although the death or
# insanity of the donor has occurred.
#
# I. Where valuable consideration has been made
#
# II. Where it is given to a lawyer
#
# III. The power given is for a fixed period only
#
# IV. Where it is given to Amanah Raya Berhad
#
# A. I and III only
#
# B. II and IV only
#
# C. II and III only
#
# D. All of the above
# Expected Answer: A
# Raw LLM Response: A
#
# --------------------
# --------------------
# Question: 9. The following except one, are formalities that must be complied with, for a Power of Attorney
# to be valid
#
# A. Must be executed and authenticated before specific individuals
#
# B. Must be filed in the High Court
#
# C. Must always be revoked upon death of the Donor
#
# D. Must clearly specify the powers given to the Donee
# Expected Answer: C
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 10. Common examples of the use of POA are all the following except
#
# A. Land transactions
#
# B. Partnerships
#
# C. Application of Grant of Representations overseas
#
# D. Bankruptcy Petitions
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 1. The following statements concern Personal Representatives. Which of these are correct?
#
# I. A personal representative is always in a position of trust and this relates to the relationship between the appointed person(s) and the beneficiaries.
#
# II. A personal representative cannot be sued by the beneficiaries for breaches in duty
#
# III. A personal representative is free to delegate any duty of his choosing for others to assist him.
# IV. Apersonal representative has to declare all potential conflicts of interest to the beneficiaries to avoid future misunderstandings.
#
# A. I and II only
#
# B. II and III only
#
# C. II and IV only
#
# D. I and IV only
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 2. With reference to Personal Representatives, which one of the following statements is not correct?
#
# I. By law,  executors  or administrators  of an  estate are  personal  representatives  of  the estate.
#
# II. A female personal representative named in the will is called an Executrix.
#
# III. Both executors and administrators have similar responsibilities when administering    the estate.
#
# IV. The minimum age to be appointed a personal representative is 21.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. IV only
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 3. With reference to the power of Personal Representatives, which of the following statements(s) is/are correct?
#
# I. It is possible that an appointed person in a Will or by the court is both a trustee and a personal representative.
# II. Whether testacy or intestacy and before the estate is fully administered, the personal representative holds the estate vested in him for carrying out his functions.
# III. During the administration period, the court can hold the personal representative both as trustee and executor or administrator as he holds legal title to the property.
# IV. If a trustee carries on the business left by the deceased estate owner, he does so at his own risk even if the beneficiaries allow him to do so.
#
# A. I and II only
#
# B. II and III only
#
# C. I and III only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 4. Trusts are useful instruments in estate planning, which one of the following statements is not correct?
#
# A. In a trust property, the beneficiary and the trustee jointly hold the legal title.
#
# B. In a trust property, beneficiary holds the beneficial interest to the property whilst the trustee the legal title.
#
# C. The original owner of the trust property is called the Settlor.
#
# D. The beneficiary has legally enforceable rights that enable them to defend and protect their interest in the trust.
# Expected Answer: A
# Raw LLM Response: A
#
# --------------------
# --------------------
# Question: 5. Which of these statement(s) is/are correct concerning the organising of the properties after the grant of probate is obtained?
#
# A. The executor needs to place all assets owned by the deceased under his control.
#
# B. The executor needs to settle all the deceased testator's debts and liabilities
#
# C. After all debts and liabilities have been settled, the executor must distribute the assets according to the wishes of the testator.
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 6. Which of the following is/are correct with reference to settlement of debts and liabilities?
#
# A. Payable debts include both personal and business debts.
#
# B. The Trustees Act provides wide ranging powers to the executor to deal with the property of the deceased and claims against the estate.
#
# C. Payable debts are ranked with funeral first, and then testamentary expenses before creditors of the estate.
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 7. The Distribution Act 1958 applies to the following with the exception of
#
# A. Peninsular Malaysia
#
# B. Sabah
#
# C. Sarawak
#
# D. Wilayah Persekutuan
# Expected Answer: B
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 8. An executor de son tort is .
#
# A. The person appointed to administer the remainder of the estate upon the death, retirement or resignation of the Executor.
#
# B. The person appointed by the last Executor to replace him.
#
# C. The person appointed in the Will as the Executor.
#
# D. A person who acts in someway as if he is the Executor, intermeddling with the estate
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 9. What type of application needs to be made when a person dies with a valid Will?
#
# A. Letters of Administration
#
# B. Grant of Probate
#
# C. Letter of Administration with Will Annexed
#
# D. Grant of Will
# Expected Answer: B
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 10. If the personal representative is unsure of how to deal with the estate, who should the personal representative ask for direction?
#
# A. Close Friends of the family
#
# B. The Beneficiaries
#
# C. The Lawyer
#
# D. The Court
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 1. Which of these statements is not correct concerning Life Insurance used in estate planning?
#
# A. Life insurance proceeds are considered part of the estate.
#
# B. Policies protected under statutory trusts are out of reach of creditors.
#
# C. Life insurance proceeds are liable to be taxed
#
# D. Life insurance may also provide for critical illnesses expenses that can erode the value of an estate.
# Expected Answer: C
# Raw LLM Response: A
#
# --------------------
# --------------------
# Question: 2. Which of the statements below are correct with reference to the use of life insurance for estate planning?
#
# I. If the nominee is the brother of the insured, the brother will be considered the executor and must distribute the proceeds received in accordance with the Will of the insured.
# II. Policies held under statutory trusts cannot be assigned or pledge as security without the written consent of the trustee.
# III. The Public Trustee will act only where there are no competent nominees and no surviving parent available to act as trustees concerning policy monies held under statutory trust.
#
# A. I and II only
#
# B. II and III only
#
# C. I and III only
#
# D. All are correct
# Expected Answer: D
# Raw LLM Response: A
#
# --------------------
# --------------------
# Question: 3. Concerning nomination in a life policy, all are correct, except:
#
# A. Subsequent nominations by the policy owner will revoke earlier nominations.
#
# B. Under Paragraph 5 (1) Of Schedule 10 of the FSA 2013, a statutory trust  is created for all Malaysians if the nominee is his parent, spouse or children.
#
# C. The Public Trustee may also be the trustee of policy moneys in some circumstances.
#
# D. Under Paragraph 5 (1) Of Schedule 10 of the FSA 2013, only the death claim proceeds are protected from the creditors.
# Expected Answer: B
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 4. Which of the following are true in life insurance policies?
#
# I. Only natural persons may be named as nominees
# II. When death claims are payable the insurer must pay the policy moneys to the nominees in full
# III. "Non-trust" nominees shall receive policy moneys as executors of the estate of the deceased policy owner
# IV. If it is intended to give moneys beneficially to "non-trust" nominees, policy benefits must be assigned to such nominees.
#
# A. I and II only
#
# B. II and III only
#
# C. II and III and IV only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 5. Which of the following are true of Assignments?
#
# I. The legal effect of assignments is to transfer ownership or legal title to another
# II. May be Absolute or Conditional for the benefit of the assignee
# III. Nominees of "non-trust" insurance policies will receive the policy moneys beneficially if the policy moneys are assigned in their favour otherwise they receive the moneys in the capacity of executors
# IV. When polices are assigned for the purpose of collateral, the insurer shall pay to the nominee the balance of moneys in excess of that which is necessary to satisfy the assignee
#
# A. I and II only
#
# B. II and III only
#
# C. II and III and IV only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 6. The following except one, are features of a statutory trust of life insurance for Non-Muslims
#
# A. Establishes a fund which is free from creditors
#
# B. The beneficiaries of a statutory trust are confined to parents, children and spouses.
#
# C. The receipt of trustees gives full discharge to insurers
#
# D. The policy ownerâ€Ÿs declaration in a will may be used to revoke the terms of the trust.
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 7. Which of the following is NOT applicable to absolute assignments?
#
# A. It may be used as a collateral for a loan
#
# B. It may be sold for the cash value of a life policy
#
# C. It may be used to create a gift of a life policy
#
# D. It may be revoked by the directions in a will
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 8. A Conditional Assignment may be created to
#
# A. give rights to an assignee to claim the policy moneys upon the death of an assignor
#
# B. revert all rights to the assignor under certain conditions
#
# C. to give policy moneys to a named nominees beneficially
#
# D. all the above
# Expected Answer: D
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 9. Which one of the following nominees in a life policy may not create a "statutory trust"
#
# A. daughter
#
# B. spouse
#
# C. adopted son
#
# D. mother
# Expected Answer: D
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 10. A policy owner dies leaving his brother as a nominee of the policy moneys. Which one of the following is an accurate statement?
#
# A. The policy moneys are considered part of the estate to satisfy the deceasedâ€Ÿs debts.
#
# B. The brother is entitled to the moneys after paying all debts.
#
# C. The brother must apply for letter of administration to receive the claim.
#
# D. The wife of the deceased may also be recognised as a claimant by the insurance company.
# Expected Answer: A
# Raw LLM Response: A
#
# --------------------
# --------------------
# Question: 1. For business owners in the planning of their estate involving Keyman protection and Buy-Sell
# agreements, which of the following is / are relevant?
#
# I. Partnership Act 1967
#
# II. Companies Act 1965
#
# III. Registration of Business Act 1956
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 2. Settlement options for businesses are varied. Which of the statement(s) is/are correct?
#
# I. When a sole proprietor dies, the business entity legally ceases to exist.
#
# II. If a personal representative runs the business and fails, he will not be personally liable for
# the losses.
#
# III. A loss of value to the estate due to liquidation does not affect the legal representative
# personally.
#
# A. I and II only
#
# B. II and III only
#
# C. I and III only
#
# D. None of the above
# Expected Answer: C
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 3. Which of the following statement(s) is/are correct concerning Buy-Sell arrangements in a sole
# proprietorship?
#
# I. To avoid the risk of "no suitable takers" for a sole proprietorship, it may be prudent to pre-
# arrange the sale of the business to an employee or an interested third party.
#
# II. Life insurance can be used to bind both parties in a proprietorship buy-sell agreement.
#
# III. A key employee can rely on a continuing source of income upon the death of his boss
# should he agree to a pre-arranged buy-sell agreement.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 4. With reference to liabilities in partnerships, which of the following is/are correct?
#
# I. All partners of a general partnership are exposed jointly to unlimited liabilities of the
# enterprise that is of a contractual nature.
#
# II. All partners are jointly and severally liable for wrongs, torts and crimes.
#
# III. Having unlimited liability means the personal assets may be exposed by the partnership
# liabilities that go beyond the partner's capital contributions and their share of profits.
#
# IV. The estate of a deceased partner is not liable for the debts of the partnership incurred
# during the time of the deceased partner's tenure.
#
# A. I and II only
#
# B. II and III only
#
# C. I and III only
#
# D. All of the above
# Expected Answer: C
# Raw LLM Response: C
#
# --------------------
# --------------------
# Question: 5. A company has a distinct and separate legal identity form the people who own or create it.
# However, should the principle shareholder die, there are many issues to consider. Which of the
# following is/are correct?
#
# I. There may be conflict between the needs of the surviving shareholders and the widow of
# the deceased shareholder.
#
# II. The surviving shareholders may buy over the shares of the deceased shareholder.
#
# III. The surviving shareholders may try to continue the business with the deceased's family.
#
# IV. The surviving shareholders may sell their shares to the deceased's estate.
#
# A. I and II only
#
# B. II and III only
#
# C. III and I only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 6. Assuming a company is growth focused, which of the following is/are correct concerning issues
# faced by widows of deceased shareholders?
#
# I. Upon the demise of a minority shareholder, the widow of the deceased shareholder can
# demand dividend payments from the company and the company has to comply.
#
# II. The widow of a deceased majority shareholder can demand for dividend payments from
# the company and the company is likely to comply.
#
# III. The widow of a deceased equal shareholder can demand for dividend payments from the
# company and the company is likely to comply.
#
# IV. All of the above
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All of the above
# Expected Answer: B
# Raw LLM Response: B
#
# --------------------
# --------------------
# Question: 7. To overcome future problems for survivors of business owners, which of these statement(s)
# is/are correct?
#
# I. A Buy-Sell Agreement is a useful arrangement to overcome problems for survivors of
# deceased business owners.
#
# II. A Buy-Sell Agreement provides shareholders with a fair price for their shares upon their
# demise.
#
# III. One important issue in a Buy-Sell Agreements is the determination of the source of the
# money when needed.
#
# IV. All of the above
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 8. Which of the statement(s) is/are correct concerning the impact of death or disability of a Keyman
# to a business organisation?
#
# I. There can be loss of credit worthiness in the eyes of creditors.
#
# II. There may be a loss of goodwill.
#
# III. The driving force and leadership of a keyman may be difficult to replace in a business
#
# IV. Employees of the business may suffer a loss of confidence.
#
# A. I and II only
#
# B. II and III only
#
# C. III and IV only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------
# --------------------
# Question: 9. Which of the statements is/are correct concerning Partnerships?
#
# I. A partnership exists as a separate legal entity
#
# II. In the absence of an agreement which provides for continuation, the death of a partner
# ends the partnership as a business entity.
#
# III. Partners in a partnership are agents for each other and thus can make each other liable
# for business obligations contracted in a partnership.
#
# IV.   The unlimited liability of each and every partner is a major concern for the estate of each partner.
#
# A. All are correct except (I)
#
# B. All are correct except (II)
#
# C. All are correct except (III)
#
# D. All are correct except (IV)
# Expected Answer: A
# Raw LLM Response: A
#
# --------------------
# --------------------
# Question: 10. Which of the following statements are correct?
#
# I. Keyman insurance is considered an important business planning tool.
#
# II. Keyman insurance helps indemnify losses of the company.
#
# III. Keyman insurance provides a business reserve fund.
#
# IV. Keyman insurance can help strengthen a business's credit status.
#
# A. I and II only
#
# B. III and IV
#
# C. III and I only
#
# D. All the above
# Expected Answer: D
# Raw LLM Response: D
#
# --------------------

# %% [markdown]
# ### Evaluation

# %%
# Calculate and print accuracy
total_questions = sum(len(questions_list) for questions_list in questions_data.values())
accuracy = (correct_answers / total_questions) * 100 if total_questions > 0 else 0

print(f"\nValidation Results:")
print(f"Total Questions: {total_questions}")
print(f"Correct Answers: {correct_answers}")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# Validation Results:
# Total Questions: 80
# Correct Answers: 61
# Accuracy: 76.25%

# %% [markdown]
# ## Refined RAG Pipeline - Unstructured & LangChain

# %% [markdown]
# ### Using Unstructured to Process PDFs

# %%
from unstructured.partition.pdf import partition_pdf
import os

pdf_elements = []
pdf_dir = "data/5_estate_planning/Lessons"

for filename in os.listdir(pdf_dir):
    if filename.lower().endswith(".pdf"):
        file_path = os.path.join(pdf_dir, filename)
        print(f"Processing file: {file_path}")
        
        # Returns a List[Element] present in the pages of the parsed pdf document
        # Applies the English and Malay language pack for ocr. OCR is only applied if the text is not available in the PDF.
        elements = partition_pdf(file_path, languages=["eng", "msa"])

        pdf_elements.extend(elements)
# Out:
# Processing file: data/5_estate_planning/Lessons\1. Chapter 1  The Concepts and Fundamentals of Estate Planning.pdf
# Processing file: data/5_estate_planning/Lessons\2. Chapter 2  Testacy and Intestacy.pdf
# Processing file: data/5_estate_planning/Lessons\3. Chapter 3  Estate of Muslims.pdf
# Processing file: data/5_estate_planning/Lessons\4. Chapter 4  Trusts.pdf
# Processing file: data/5_estate_planning/Lessons\5. Chapter 5  Powers of Attorney.pdf
# Processing file: data/5_estate_planning/Lessons\6. Chapter 6  Personal Representatives Duties and Powers.pdf
# Processing file: data/5_estate_planning/Lessons\7. Chapter 7  Life Insurance and Estate Planning.pdf
# Processing file: data/5_estate_planning/Lessons\8. Chapter 8  Estate Planning for Business Owners.pdf
# Processing file: data/5_estate_planning/Lessons\Estate Planning-13-15.pdf

# %%
for element in pdf_elements[:10]:
    print(f"{element.category.upper()}: {element.text}")
# Out:
# HEADER: RFP Programme - Module 5
# HEADER: Chapter 1 : The Concepts and Fundamentals of Estate Planning
# TITLE: Chapter 1
# TITLE: The Concepts and Fundamentals of Estate Planning
# TITLE: Chapter Objectives
# NARRATIVETEXT: On completion of this chapter you should have a basic knowledge on:
# LISTITEM: The Purpose and Importance of Estate Planning
# LISTITEM: The Major Steps in the Estate Planning Process
# LISTITEM: The Legal Rules and Principles Applicable in the Estate Planning Process
# LISTITEM: The Principal Tools and Legal Instruments Use in Estate Planning

# %% [markdown]
# #### Understanding the elements in the PDF

# %%
import collections

pdf_categories = [el.category for el in pdf_elements]
collections.Counter(pdf_categories)
# Out:
# Counter({'NarrativeText': 981,
#          'Title': 776,
#          'ListItem': 236,
#          'UncategorizedText': 222,
#          'Footer': 210,
#          'Header': 206})

# %% [markdown]
# #### Removing Noise (Header & Footer)

# %%
# Filter out elements that are likely headers or footers
# Assuming headers/footers are categorized as 'Header' or 'Footer' in element.category

filtered_elements = [
    el for el in pdf_elements
    if el.category.lower() not in ['header', 'footer']
]

print(f"Filtered elements count: {len(filtered_elements)}")
# Out:
# Filtered elements count: 2215

# %%
pdf_categories = [el.category for el in filtered_elements]
collections.Counter(pdf_categories)
# Out:
# Counter({'NarrativeText': 981,
#          'Title': 776,
#          'ListItem': 236,
#          'UncategorizedText': 222})

# %% [markdown]
# ### Indexing with LangChain

# %%
from langchain_core.documents import Document

documents = []
for element in filtered_elements:
    metadata = element.metadata.to_dict()
    del metadata["languages"]
    del metadata["coordinates"] # remove dictionaries to prevent errors
    metadata["source"] = metadata["filename"]
    documents.append(Document(page_content=element.text, metadata=metadata))

# %%
import chromadb
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name=embedding_model)
vectorstore = Chroma.from_documents(documents, embeddings)

retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 6}
)
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given

# %%
from langchain.prompts.prompt import PromptTemplate

# ANSWER SELECTION: Construct the query with explicit instructions to only return the letter answer
template = """
        You are an agent designed to answer a multiple choice question from the given context.
        You must respond with ONLY the letter of the correct answer: A, B, C, or D.
        Do NOT include any explanation, reasoning, or extra text.
        If you include anything other than A, B, C, or D, your answer will be considered invalid. \n
        Question: {question}
        =========
        {context}
        =========
        """
prompt = PromptTemplate(template=template, input_variables=["question", "context"])

# %%
from langchain_google_genai import ChatGoogleGenerativeAI 
from langchain.chains import RetrievalQA

llm = ChatGoogleGenerativeAI(
    model=llm,
    api_key=api_key,
    generate_kwargs={"max_output_tokens": 1}  # only one answer "A, B, C, D"
)

qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    return_source_documents=False,
    chain_type_kwargs={"prompt": prompt}
)

# %%
correct_answers = 0

for chapter_key, questions_list in questions_data.items():
    for question_entry in questions_list:
        question_text = question_entry['question']
        expected_answer = question_entry['answer']

        # Run the QA chain
        result = qa_chain.invoke({"query": question_text})
        raw_response = result["result"] if isinstance(result, dict) and "result" in result else str(result)

        print("-" * 20)
        print(f"Question: {question_text}")
        print(f"Expected Answer: {expected_answer}")
        print(f"Raw LLM Response: {raw_response}")
        print("-" * 20)

        # ANSWER SELECTION: Use regex to extract the predicted answer (a single uppercase letter A-D)
        match = re.search(r'[A-D]', raw_response.strip().upper())
        predicted_answer = match.group(0) if match else None

        if predicted_answer == expected_answer:
            correct_answers += 1

        time.sleep(delay) # Add a small delay to avoid hitting API rate limits
# Out:
# --------------------
# Question: 1. In Estate Planning there are many views and approaches taken. Which of the following is not true?
#
# A. It is common for many Malaysians to avoid estate planning
#
# B. Writing a Will is adequate for estate planning purposes
#
# C. People generally tend to avoid estate planning because it is a complex subject.
#
# D. Preservation of the estate is a key objective in estate planning
# Expected Answer: B
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 2. The various steps in the process of estate planning ensure that all issues are covered. Which of the following sequence in the process is correct?
#
# A. Set Objectives â€“ Gather information â€“ Implement â€“ Develop a plan â€“ Review
#
# B. Set Objectives â€“ Gather information â€“ Review â€“ Implement â€“ Develop a plan
#
# C. Gather information â€“ Set Objectives â€“ Review â€“ Implement â€“ Develop a plan
#
# D. Set Objectives â€“ Gather information â€“ Develop a plan â€“ Implement â€“ Review
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 3. The following statement(s) is/are not correct:
#
# I. Accumulation, Conservation and Distribution are issues that a person needs to address in his life-time.
#
# II. Assets held in joint names are not considered as part of the estate of a deceased co-owner.
#
# III. Debts, royalties and rights to compensation damages are included in an estate of a deceased.
#
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All the above
# Expected Answer: B
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 4. There are many purposes of estate planning, which of the following statement(s) is/are correct?
#
# I. Ensure liquidity for cost of transfer fees and expenses
#
# II. Assets are sufficient to meet objectives
#
# III. Minimise depleting the value of assets
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 5. Included in the several phases of estate planning are various considerations. Which of the following is not correct?
#
# A. Ensure that a desired lifestyle is definitely possible
#
# B. Wealth creation is the logical start for estate planning
#
# C. Life insurance helps in wealth creation
#
# D. Estate shrinkage can be due to unpaid income taxes
# Expected Answer: A
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 6. Upon death, the property of a deceased estate owner passes to other in a number of ways. Which of the following is/are correct?
#
# A. By validating the will through the courts
#
# B. By assignment of title of immovable assets
#
# C. By mechanism of survivorship
#
# D. All the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 7. During the Implementation stage of the estate plan, which of the following is not important?
#
# A. Execution of all necessary legal documents
#
# B. Ensure marital stability and family harmony
#
# C. Provide for liquidity emergencies
#
# D. Objectives of estate owner and mechanisms must be consistent
# Expected Answer: B
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 8. Concerning ownership of property, which statement is not correct?
#
# A. Under term interest, the right to process, use and derive income ceases at the end of the term
#
# B. The holder of an unlimited interest in the property has outright ownership
#
# C. Participants in a tenancy in common have survivorship rights
#
# D. Participants in a joint tenancy have survivorship rights
# Expected Answer: C
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 9. The following statements are about objectives of an estate plan. Which of the statement(s) is/are correct?
#
# I. The ultimate purpose of an estate plan is to facilitate the transfer of beneficial interest of the assets to the trustees
#
# II. It is important to understand the needs of each beneficiary in order to match the most appropriate distribution item.
#
# III. Beneficiaries need to await completion of the probate or administration process before receiving the distribution.
#
# A. I and II only
#
# B. II and III only
#
# C. I and III only
#
# D. All of the above
# Expected Answer: B
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 10. Which one of the following is not an Estate Planning tool.
#
# A. Will
#
# B. Trust
#
# C. Tenancy Agreement
#
# D. Power of Attorney
# Expected Answer: C
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 1. The following statements relate to Probate Estates. Which of the statement(s) is/are correct?
#
# I. The Will determines the distribution of all the assets of the deceased
#
# II. Probate estate encompasses all property passed to others by a Will.
#
# III. The law that prescribes the rules for the grant of representation in Malaysia is the Distribution (Amendment) Act 1997.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All of the above
# Expected Answer: B
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 2. The probate process proves the validity of the Will and it addresses many issues. Which one of the following is not correct?
#
# I. Settlement of the estate
#
# II. Distribution of the entire assets of the deceased
#
# III. Avoids disputes pertaining to the deceased owner's Will
#
# IV. Appointment of personal representatives of the estate
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. IV only
# Expected Answer: B
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 3. Which one of the following statements is not correct?
#
# I. If an estate owner dies without a valid will, all probate property passes under the laws of intestate succession.
#
# II. Non-probate property are those that are passed on to beneficiaries by operation of law or by contract.
#
# III. Life insurance policies assigned either conditionally or absolutely to third parties are non-probate assets.
#
# IV. Tenancy in common is an example of transfer by operation of law.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. IV only
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 4. A number of legislations impact estate planning. Which of the following is no longer relevant?
#
# A. Wills Act 1959 (Revised 1998)
#
# B. Probate and Administration Act 1959 (revised 1972)
#
# C. Finance (Estate Duty) Act 1980 (Amended 1984)
#
# D. Distribution (Amendment) Act 1997
# Expected Answer: C
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 5. The purposes of preparing a Will should be made known. Which of the statement(s) is/are correct?
#
# A. Ensuring the right people handle the testator's property.
#
# B. Ensuring the right people receive the property.
#
# C. Ensuring a smooth transfer of the deceased's property.
#
# D. All the above are correct.
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 6. With reference to the validity of a Will for Non-Muslims which of the statement(s) is/are correct?
#
# I. All Wills must fully comply with the provisions of the Wills Act 1959.
#
# II. The testator must be of sound mind.
#
# III. The Will must be in writing.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 7. Which of the following is not correct concerning Wills?
#
# A. A Will can also be made by persons aged less than 18.
#
# B. The mode of execution of the Will is a factor to take into account for a valid Will.
#
# C. Oral Will does not comply with the Wills Act 1959
#
# D. There has to be two witnesses to the will.
# Expected Answer: A
# Raw LLM Response: A
# --------------------
# --------------------
# Question: 8. Which of these statement(s) is/are correct concerning Wills and Probate?
#
# A. The probate process is for the purpose of proving that the Will is valid.
#
# B. The probate process gets the Will and the executor named in the Will to be legally approved by the Court.
#
# C. There are specific rules and procedures to follow in the probate process.
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 9. The Distribution Act 1958 (and the Amendment Act 1997) applies to
#
# A. Peninsular Malaysia and Sabah only.
#
# B. Peninsular Malaysia and Sarawak only.
#
# C. Sabah and Sarawak only.
#
# D. The whole of Malaysia.
# Expected Answer: B
# Raw LLM Response: A
# --------------------
# --------------------
# Question: 10. When a testator signs a Will, the witnesses .
#
# A. Need to sign in isolation but do not need to read the Will.
#
# B. Need to sign in the presence of the testator but do not need to read the Will.
#
# C. Need to read the Will in the presence of each other
#
# D. Need to read the Will in the presence of the testator.
# Expected Answer: B
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 1. For Muslims, estate planning may be more structured. Which of the following statement(s)
# is/are correct?
#
# I. The Wills Act 1959 does not apply to Muslims making a Will in Malaysia.
#
# II. For distribution of property the Syariah laws of the Shaffi School of Islamic Jurisprudence
# applies.
# III. Property acquired during marriage is called Harta Sepencarian and will pass on to the
# surviving spouse and children.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All of the above
# Expected Answer: C
# Raw LLM Response: A
# --------------------
# --------------------
# Question: 2. The terminology used that relates to estate planning for Muslims include the following. Which
# amongst the list is not correct?
#
# I. The Wasiat is a Muslim will.
#
# II. Gifts given away inter vivos is called Hibah.
#
# III. Faraid refers to testate distribution of Muslim property.
#
# IV. Baitulmal refers to funds of the Muslim community
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. IV only
# Expected Answer: C
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 3. Which of the following of the hukum faraid distribution are correct?
#
# I. If the wife dies leaving a husband, son and daughter, the husband is entitled to Â¼ of the
# estate, the son Â½ and the daughter Â¼.
# II. If there are no children and the husband survives the wife, the husband receives Â½ of the
# estate and the balance goes to Baitulmal.
# III. If the husband dies leaving a wife, son and daughter, the wife receives 1/8, the son 7/12,
# the daughter 7/24.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All are correct
# Expected Answer: D
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 4. Muslims are advised to write a will. The main advantage is
#
# A. The entire estate may be given to non legal heirs if desired
#
# B. It would be easier to administer the estate because of the Probate process.
#
# C. The estate distribution need not follow hukum faraid principles
#
# D. At least two-thirds of the estate may be given to non-muslims if desired.
# Expected Answer: B
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 5. With reference to administration of the estates of Muslim. Which of the following are true?
#
# I. The Wills Act 1959 applies to Muslims
#
# II. The Probate and Administration Act 1959 applies to Muslims
#
# III. The Statutory Trust created by Paragraph 5 of Schedule 10 (Section 130) of Financial
# Services Act 2013 does not apply to Muslims
# IV. Muslims are not allowed to apply for administration under the Small Estates (Distribution)
# Act 1955.
#
# A. I and II only
#
# B. I and III only
#
# C. II and III only
#
# D. II and IV only
# Expected Answer: C
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 6. Which of the following are true?
#
# I. Non-Muslims cannot inherit form the estate of a Muslim
#
# II. A Muslim testator can Will away at least one-quarter of his estate to non legal heirs.
#
# III. By means of a valid disposition, a Muslim can give away less than one-third of his estate
# to Non-Muslims.
#
# A. I and II only
#
# B. I and III only
#
# C. II and III only
#
# D. All the above
# Expected Answer: D
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 7. During their life-time, Muslims are allowed to give inter-vivos gifts. The following, except one
# are examples of such gifts
#
# A. Transfer of house
#
# B. Absolutely assignment of a life insurance policy
#
# C. Naming a nominee of life insurance policy moneys
#
# D. Irrevocable trusts
# Expected Answer: C
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 8. The â€žSijil Faraidâ€Ÿ is
#
# A. Given by the High Court
#
# B. Equivalent to the Letters of Administration
#
# C. A Certificate confirming the benefit of the legal heirs
#
# D. A Distribution Order given by Amanah Raya Bhd
# Expected Answer: C
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 9. Upon the death of a EPF contributor, who is a Muslim. The moneys are paid
#
# A. only upon obtaining the Sijil Faraid
#
# B. only after the Will has gone through the Probate process
#
# C. to the named nominee
#
# D. only to the administrator of the estate.
# Expected Answer: C
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 10. Which one of the following features of the Islamic law of distribution is true?
#
# A. The wife of the deceased is always entitled to a quarter of the estate
#
# B. The husband of the deceased always inherits half the estate
#
# C. The wife of the deceased inherits the whole estate if she is the only legal heir surviving
#
# D. Where the deceased leaves one daughter as the only legal heir, she inherits only half the
# estate
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 1. With reference to Trustees, which of the following statement(s) is/are correct?
#
# I. The powers of the trustee are governed by an Act of Parliament.
#
# II. The court cannot step in should a trustee fail in carrying out his duty.
#
# III. A maximum of five trustees can be appointed for family trusts.
#
# IV. In the absence of trustees the benefit of a trust is still effective.
#
# A. I and II only
#
# B. II and III only
#
# C. II and IV only
#
# D. I and IV only
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 2. Which of these statements is not correct with reference to the uses of trusts in estate planning?
#
# A. The trustee has a fiduciary duty to act in the interest of the beneficiaries.
#
# B. A trust creates an equitable obligation that is strictly imposed by the court of law
#
# C. Trust properties are those assets that have been transferred to the trustee to be held for the benefit of beneficiaries.
# D. The Trustee Act 1949 defines the duties of the trustee and it overrides the trust deed.
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 3. Which of the statements below are correct with reference to the components of trusts?
#
# I. A life insurance policy assigned to a trustee for the beneficiaries is part of the 'Trust Corpus' or assets of the trust.
# II. The trust deed can provide instructions to the trustees to manage and distribute life insurance proceeds irrespective whether the life policy was created through statutory or non-statutory means.
# III. Beneficiaries have legally enforceable rights that enable them to defend and protect their interest in the trust.
#
# A. All are correct except (I)
#
# B. All are correct except (II)
#
# C. All are correct except (III)
#
# D. All are correct
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 4. With reference to the classification of trusts, which of the following is/are correct?
#
# I. The naming of nominees who are spouse, children or parents (where there is no spouse or child) in a life policy creates a Statutory Trust.
# II. Should a settlor set up a trust without naming or identifying the beneficiary, a Resulting Trust is formed where the beneficial interest reverts back to the settlor.
# III. Where the settlor has specified exact interest or share proportions for beneficiaries in the trust, a Fixed Trust has been set up.
# IV. In a Discretionary Trust, the trustee has the discretion to decide on how much of the trust property is to be distributed for each beneficiary.
#
# A. All of the above
#
# B. I and II only
#
# C. II and III only
#
# D. III and IV only
# Expected Answer: A
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 5. With reference to Testamentary Trusts, which of these statements is not correct?
#
# I. This is trust created by means of the will following the testator's death.
#
# II. The trust can only come into effect after probate has been obtained.
#
# III. Secrecy of assets and contents of a testamentary trust can be kept confidential after the death of a testator.
# IV. A testamentary trust will become irrevocable upon the death of the testator.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. IV only
# Expected Answer: C
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 6. When a trust is created, who has legal title and equitable ownership?
#
# A. Beneficiary (legal title) and Trustee (equitable ownership).
#
# B. Beneficiary (legal title) and Settlor (equitable ownership).
#
# C. Trustee (legal title) and Beneficiary (equitable ownership).
#
# D. Trustee (legal title) and Settlor (equitable ownership).
# Expected Answer: C
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 7. Chan transfers property to Lim and directs that the income derived shall be paid to Angela. Which of the following is the right option
#
# A. Chan (Beneficiary), Lim (Trustee), Angela (Settlor)
# B. Chan (Settlor), Lim (Beneficiary), Angela (Trustee)
# C. Chan (Trustee), Lim (Settlor), Angela (Beneficiary)
# D. Chan (Settlor), Lim (Trustee), Angela (Beneficiary)
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 8. Which of the following is not true with reference to the general principles of trusts?
#
# A. A settlor transfers legal ownership to trustees
#
# B. Trusts may be created by a Will
#
# C. Beneficiaries may not be trustees
#
# D. Trustees must consult the settlor in all dealings concerning the trust
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 9. What is a testamentary trust?
#
# A. It is a trust created under a Will and is revocable before the Testator's death.
#
# B. It is a trust created under a Power of Attorney and is never irrevocable until the Donor's death.
# C. It is a trust created by operation of law.
#
# D. It is a trust created by court
# Expected Answer: A
# Raw LLM Response: A
# --------------------
# --------------------
# Question: 10. In his Will, Mr Tan leaves "the majority of my shares in Genting Resorts Bhd to Mr Chin for the benefit of my children". What is the consequence of this instruction?
#
# 1. The trust will fail for lack of certainty of objects (beneficiaries)
#
# 2. The trust will fail for lack of certainty of subject matter
#
# 3. The trust will fail for lack of certainty of words
#
# 4. The shares will be part of a Resulting Trust in favour of the children only
#
# 5. The shares will become part of the residue
#
# A. 1 and 4 only
#
# B. 2 and 5 only
#
# C. 3 and 5 only
#
# D. 1,2 and 4 only
# Expected Answer: B
# Raw LLM Response: A
# --------------------
# --------------------
# Question: 1. With reference to a Power of Attorney, which of the following statement(s) is/are
# correct?
#
# I. The Durable Power of Attorney authorises a trusted person to make financial decisions for
# an individual should the person become unable to do so himself.
#
# II. The person appointed in the Durable Power of Attorney is called the Attorney or Donee
#
# III. The death or mental incapacity of the Donor revokes a simple Power of Attorney.
#
# IV. The death or legal incapacity or bankruptcy of the Donee revokes a Power of attorney.
#
# A. I and II only
#
# B. II and III only
#
# C. I and III only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 2. On matters relating to the Power of Attorney, which of these is not correct?
#
# I. A Power of Attorney can be made irrevocable or durable where there is valuable
# consideration given and is expressed to be irrevocable.
# II. Where a Power of Attorney is made irrevocable for a fixed period it cannot be revoked by
# the death of the donor during that period.
#
# III. Under a General Power of Attorney the attorney can handle all the donor's insurance
# needs and claims.
# IV. Under  a  General  Power  of  Attorney  the  attorney  cannot  file  tax  returns  and make
# payments.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. IV only
# Expected Answer: D
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 3. What is a Power of Attorney?
#
# A. A power granted by Court to a Trustee to execute the Trust Deed
#
# B. An assignment by an assignor to an assignee
#
# C. A power granted by Court to an executor to execute the Will
#
# D. An instruction by which a Donor may formally authorise a Donee to act on his behalf or be
# his agent.
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 4. A Power of Attorney operates on the following principles:-
#
# A. Contractual Principles
#
# B. Tort Principles
#
# C. Trust Principles
#
# D. Agency Principles
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 5. Which of the following usually revoke a Power of Attorney?
#
# I. Death
#
# II. Marriage
#
# III. Divorce
#
# IV. Not in the country
#
# V. Bankruptcy
#
# A. IV only
#
# B. I and V only
#
# C. I and II and V only
#
# D. I and II and IV only
# Expected Answer: B
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 6. In order to be valid a Power of Attorney must be registered/deposited with:
#
# A. Land Office
#
# B. High Court
#
# C. Department of Insolvency
#
# D. Amanah Raya Berhad
# Expected Answer: B
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 7. The Authentication of a Power of Attorney must be done before either one of the following
# persons with the exception of:
#
# A. Magistrate
#
# B. Police Inspector
#
# C. Commissioner for Oaths
#
# D. Justice of Peace
# Expected Answer: B
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 8. In what circumstances can a Power of Attorney be said to be irrevocable although the death or
# insanity of the donor has occurred.
#
# I. Where valuable consideration has been made
#
# II. Where it is given to a lawyer
#
# III. The power given is for a fixed period only
#
# IV. Where it is given to Amanah Raya Berhad
#
# A. I and III only
#
# B. II and IV only
#
# C. II and III only
#
# D. All of the above
# Expected Answer: A
# Raw LLM Response: A
# --------------------
# --------------------
# Question: 9. The following except one, are formalities that must be complied with, for a Power of Attorney
# to be valid
#
# A. Must be executed and authenticated before specific individuals
#
# B. Must be filed in the High Court
#
# C. Must always be revoked upon death of the Donor
#
# D. Must clearly specify the powers given to the Donee
# Expected Answer: C
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 10. Common examples of the use of POA are all the following except
#
# A. Land transactions
#
# B. Partnerships
#
# C. Application of Grant of Representations overseas
#
# D. Bankruptcy Petitions
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 1. The following statements concern Personal Representatives. Which of these are correct?
#
# I. A personal representative is always in a position of trust and this relates to the relationship between the appointed person(s) and the beneficiaries.
#
# II. A personal representative cannot be sued by the beneficiaries for breaches in duty
#
# III. A personal representative is free to delegate any duty of his choosing for others to assist him.
# IV. Apersonal representative has to declare all potential conflicts of interest to the beneficiaries to avoid future misunderstandings.
#
# A. I and II only
#
# B. II and III only
#
# C. II and IV only
#
# D. I and IV only
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 2. With reference to Personal Representatives, which one of the following statements is not correct?
#
# I. By law,  executors  or administrators  of an  estate are  personal  representatives  of  the estate.
#
# II. A female personal representative named in the will is called an Executrix.
#
# III. Both executors and administrators have similar responsibilities when administering    the estate.
#
# IV. The minimum age to be appointed a personal representative is 21.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. IV only
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 3. With reference to the power of Personal Representatives, which of the following statements(s) is/are correct?
#
# I. It is possible that an appointed person in a Will or by the court is both a trustee and a personal representative.
# II. Whether testacy or intestacy and before the estate is fully administered, the personal representative holds the estate vested in him for carrying out his functions.
# III. During the administration period, the court can hold the personal representative both as trustee and executor or administrator as he holds legal title to the property.
# IV. If a trustee carries on the business left by the deceased estate owner, he does so at his own risk even if the beneficiaries allow him to do so.
#
# A. I and II only
#
# B. II and III only
#
# C. I and III only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 4. Trusts are useful instruments in estate planning, which one of the following statements is not correct?
#
# A. In a trust property, the beneficiary and the trustee jointly hold the legal title.
#
# B. In a trust property, beneficiary holds the beneficial interest to the property whilst the trustee the legal title.
#
# C. The original owner of the trust property is called the Settlor.
#
# D. The beneficiary has legally enforceable rights that enable them to defend and protect their interest in the trust.
# Expected Answer: A
# Raw LLM Response: A
# --------------------
# --------------------
# Question: 5. Which of these statement(s) is/are correct concerning the organising of the properties after the grant of probate is obtained?
#
# A. The executor needs to place all assets owned by the deceased under his control.
#
# B. The executor needs to settle all the deceased testator's debts and liabilities
#
# C. After all debts and liabilities have been settled, the executor must distribute the assets according to the wishes of the testator.
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 6. Which of the following is/are correct with reference to settlement of debts and liabilities?
#
# A. Payable debts include both personal and business debts.
#
# B. The Trustees Act provides wide ranging powers to the executor to deal with the property of the deceased and claims against the estate.
#
# C. Payable debts are ranked with funeral first, and then testamentary expenses before creditors of the estate.
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 7. The Distribution Act 1958 applies to the following with the exception of
#
# A. Peninsular Malaysia
#
# B. Sabah
#
# C. Sarawak
#
# D. Wilayah Persekutuan
# Expected Answer: B
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 8. An executor de son tort is .
#
# A. The person appointed to administer the remainder of the estate upon the death, retirement or resignation of the Executor.
#
# B. The person appointed by the last Executor to replace him.
#
# C. The person appointed in the Will as the Executor.
#
# D. A person who acts in someway as if he is the Executor, intermeddling with the estate
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 9. What type of application needs to be made when a person dies with a valid Will?
#
# A. Letters of Administration
#
# B. Grant of Probate
#
# C. Letter of Administration with Will Annexed
#
# D. Grant of Will
# Expected Answer: B
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 10. If the personal representative is unsure of how to deal with the estate, who should the personal representative ask for direction?
#
# A. Close Friends of the family
#
# B. The Beneficiaries
#
# C. The Lawyer
#
# D. The Court
# Expected Answer: D
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 1. Which of these statements is not correct concerning Life Insurance used in estate planning?
#
# A. Life insurance proceeds are considered part of the estate.
#
# B. Policies protected under statutory trusts are out of reach of creditors.
#
# C. Life insurance proceeds are liable to be taxed
#
# D. Life insurance may also provide for critical illnesses expenses that can erode the value of an estate.
# Expected Answer: C
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 2. Which of the statements below are correct with reference to the use of life insurance for estate planning?
#
# I. If the nominee is the brother of the insured, the brother will be considered the executor and must distribute the proceeds received in accordance with the Will of the insured.
# II. Policies held under statutory trusts cannot be assigned or pledge as security without the written consent of the trustee.
# III. The Public Trustee will act only where there are no competent nominees and no surviving parent available to act as trustees concerning policy monies held under statutory trust.
#
# A. I and II only
#
# B. II and III only
#
# C. I and III only
#
# D. All are correct
# Expected Answer: D
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 3. Concerning nomination in a life policy, all are correct, except:
#
# A. Subsequent nominations by the policy owner will revoke earlier nominations.
#
# B. Under Paragraph 5 (1) Of Schedule 10 of the FSA 2013, a statutory trust  is created for all Malaysians if the nominee is his parent, spouse or children.
#
# C. The Public Trustee may also be the trustee of policy moneys in some circumstances.
#
# D. Under Paragraph 5 (1) Of Schedule 10 of the FSA 2013, only the death claim proceeds are protected from the creditors.
# Expected Answer: B
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 4. Which of the following are true in life insurance policies?
#
# I. Only natural persons may be named as nominees
# II. When death claims are payable the insurer must pay the policy moneys to the nominees in full
# III. "Non-trust" nominees shall receive policy moneys as executors of the estate of the deceased policy owner
# IV. If it is intended to give moneys beneficially to "non-trust" nominees, policy benefits must be assigned to such nominees.
#
# A. I and II only
#
# B. II and III only
#
# C. II and III and IV only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 5. Which of the following are true of Assignments?
#
# I. The legal effect of assignments is to transfer ownership or legal title to another
# II. May be Absolute or Conditional for the benefit of the assignee
# III. Nominees of "non-trust" insurance policies will receive the policy moneys beneficially if the policy moneys are assigned in their favour otherwise they receive the moneys in the capacity of executors
# IV. When polices are assigned for the purpose of collateral, the insurer shall pay to the nominee the balance of moneys in excess of that which is necessary to satisfy the assignee
#
# A. I and II only
#
# B. II and III only
#
# C. II and III and IV only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 6. The following except one, are features of a statutory trust of life insurance for Non-Muslims
#
# A. Establishes a fund which is free from creditors
#
# B. The beneficiaries of a statutory trust are confined to parents, children and spouses.
#
# C. The receipt of trustees gives full discharge to insurers
#
# D. The policy ownerâ€Ÿs declaration in a will may be used to revoke the terms of the trust.
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 7. Which of the following is NOT applicable to absolute assignments?
#
# A. It may be used as a collateral for a loan
#
# B. It may be sold for the cash value of a life policy
#
# C. It may be used to create a gift of a life policy
#
# D. It may be revoked by the directions in a will
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 8. A Conditional Assignment may be created to
#
# A. give rights to an assignee to claim the policy moneys upon the death of an assignor
#
# B. revert all rights to the assignor under certain conditions
#
# C. to give policy moneys to a named nominees beneficially
#
# D. all the above
# Expected Answer: D
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 9. Which one of the following nominees in a life policy may not create a "statutory trust"
#
# A. daughter
#
# B. spouse
#
# C. adopted son
#
# D. mother
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 10. A policy owner dies leaving his brother as a nominee of the policy moneys. Which one of the following is an accurate statement?
#
# A. The policy moneys are considered part of the estate to satisfy the deceasedâ€Ÿs debts.
#
# B. The brother is entitled to the moneys after paying all debts.
#
# C. The brother must apply for letter of administration to receive the claim.
#
# D. The wife of the deceased may also be recognised as a claimant by the insurance company.
# Expected Answer: A
# Raw LLM Response: A
# --------------------
# --------------------
# Question: 1. For business owners in the planning of their estate involving Keyman protection and Buy-Sell
# agreements, which of the following is / are relevant?
#
# I. Partnership Act 1967
#
# II. Companies Act 1965
#
# III. Registration of Business Act 1956
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 2. Settlement options for businesses are varied. Which of the statement(s) is/are correct?
#
# I. When a sole proprietor dies, the business entity legally ceases to exist.
#
# II. If a personal representative runs the business and fails, he will not be personally liable for
# the losses.
#
# III. A loss of value to the estate due to liquidation does not affect the legal representative
# personally.
#
# A. I and II only
#
# B. II and III only
#
# C. I and III only
#
# D. None of the above
# Expected Answer: C
# Raw LLM Response: C
# --------------------
# --------------------
# Question: 3. Which of the following statement(s) is/are correct concerning Buy-Sell arrangements in a sole
# proprietorship?
#
# I. To avoid the risk of "no suitable takers" for a sole proprietorship, it may be prudent to pre-
# arrange the sale of the business to an employee or an interested third party.
#
# II. Life insurance can be used to bind both parties in a proprietorship buy-sell agreement.
#
# III. A key employee can rely on a continuing source of income upon the death of his boss
# should he agree to a pre-arranged buy-sell agreement.
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 4. With reference to liabilities in partnerships, which of the following is/are correct?
#
# I. All partners of a general partnership are exposed jointly to unlimited liabilities of the
# enterprise that is of a contractual nature.
#
# II. All partners are jointly and severally liable for wrongs, torts and crimes.
#
# III. Having unlimited liability means the personal assets may be exposed by the partnership
# liabilities that go beyond the partner's capital contributions and their share of profits.
#
# IV. The estate of a deceased partner is not liable for the debts of the partnership incurred
# during the time of the deceased partner's tenure.
#
# A. I and II only
#
# B. II and III only
#
# C. I and III only
#
# D. All of the above
# Expected Answer: C
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 5. A company has a distinct and separate legal identity form the people who own or create it.
# However, should the principle shareholder die, there are many issues to consider. Which of the
# following is/are correct?
#
# I. There may be conflict between the needs of the surviving shareholders and the widow of
# the deceased shareholder.
#
# II. The surviving shareholders may buy over the shares of the deceased shareholder.
#
# III. The surviving shareholders may try to continue the business with the deceased's family.
#
# IV. The surviving shareholders may sell their shares to the deceased's estate.
#
# A. I and II only
#
# B. II and III only
#
# C. III and I only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 6. Assuming a company is growth focused, which of the following is/are correct concerning issues
# faced by widows of deceased shareholders?
#
# I. Upon the demise of a minority shareholder, the widow of the deceased shareholder can
# demand dividend payments from the company and the company has to comply.
#
# II. The widow of a deceased majority shareholder can demand for dividend payments from
# the company and the company is likely to comply.
#
# III. The widow of a deceased equal shareholder can demand for dividend payments from the
# company and the company is likely to comply.
#
# IV. All of the above
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All of the above
# Expected Answer: B
# Raw LLM Response: B
# --------------------
# --------------------
# Question: 7. To overcome future problems for survivors of business owners, which of these statement(s)
# is/are correct?
#
# I. A Buy-Sell Agreement is a useful arrangement to overcome problems for survivors of
# deceased business owners.
#
# II. A Buy-Sell Agreement provides shareholders with a fair price for their shares upon their
# demise.
#
# III. One important issue in a Buy-Sell Agreements is the determination of the source of the
# money when needed.
#
# IV. All of the above
#
# A. I only
#
# B. II only
#
# C. III only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 8. Which of the statement(s) is/are correct concerning the impact of death or disability of a Keyman
# to a business organisation?
#
# I. There can be loss of credit worthiness in the eyes of creditors.
#
# II. There may be a loss of goodwill.
#
# III. The driving force and leadership of a keyman may be difficult to replace in a business
#
# IV. Employees of the business may suffer a loss of confidence.
#
# A. I and II only
#
# B. II and III only
#
# C. III and IV only
#
# D. All of the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------
# --------------------
# Question: 9. Which of the statements is/are correct concerning Partnerships?
#
# I. A partnership exists as a separate legal entity
#
# II. In the absence of an agreement which provides for continuation, the death of a partner
# ends the partnership as a business entity.
#
# III. Partners in a partnership are agents for each other and thus can make each other liable
# for business obligations contracted in a partnership.
#
# IV.   The unlimited liability of each and every partner is a major concern for the estate of each partner.
#
# A. All are correct except (I)
#
# B. All are correct except (II)
#
# C. All are correct except (III)
#
# D. All are correct except (IV)
# Expected Answer: A
# Raw LLM Response: A
# --------------------
# --------------------
# Question: 10. Which of the following statements are correct?
#
# I. Keyman insurance is considered an important business planning tool.
#
# II. Keyman insurance helps indemnify losses of the company.
#
# III. Keyman insurance provides a business reserve fund.
#
# IV. Keyman insurance can help strengthen a business's credit status.
#
# A. I and II only
#
# B. III and IV
#
# C. III and I only
#
# D. All the above
# Expected Answer: D
# Raw LLM Response: D
# --------------------

# %% [markdown]
# ### Evaluation

# %%
# Calculate and print accuracy
total_questions = sum(len(questions_list) for questions_list in questions_data.values())
accuracy = (correct_answers / total_questions) * 100 if total_questions > 0 else 0

print(f"\nValidation Results:")
print(f"Total Questions: {total_questions}")
print(f"Correct Answers: {correct_answers}")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# Validation Results:
# Total Questions: 80
# Correct Answers: 65
# Accuracy: 81.25%
